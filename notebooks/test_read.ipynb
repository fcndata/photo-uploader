# %% [markdown]
# Test how to read the different images within a path and extract the meta-data.

# %%
from pathlib import Path
import os
from dotenv import load_dotenv
load_dotenv(override=True)
# Out:
# True

# %%
from datetime import datetime

def create_image_metadata_dict(folder: Path) -> dict:
    image_metadata_dict = {}
    for file in folder.iterdir():
        if file.is_dir():
            nested_dict = create_image_metadata_dict(file)
            image_metadata_dict.update(nested_dict)
        else:
            if file.suffix.lower() in ('.png','.jpg','.mov','.mp4'):
                filename = file.name  # Extract filename without extension
                try:
                    parsed_time = datetime.strptime(file.stem, "%Y-%m-%d %H.%M.%S")
                    
                    image_metadata_dict[filename] = {
                        'img_url': file.as_posix(),
                        'filename': filename,
                        'folderpath':file.parent.as_posix(),
                        'file_suffix':file.suffix,
                        'timestamp': parsed_time
                    }
                    print(f"Parsed time for {filename}: {parsed_time}")
                except ValueError:
                    image_metadata_dict[filename] = {
                        'img_url': file.as_posix(),
                        'filename': filename,
                        'folderpath':file.parent.as_posix(),
                        'file_suffix':file.suffix,
                        'timestamp': None
                    }

    return image_metadata_dict

# %% [markdown]
# Great, now it's working, I could update an  image into my google photo so great we get this MVP
#
# Now, I would like to make the project more modular, Having said that, I would like prove this "MVP" into a

# %%
base_path = Path(os.environ['FOLDER_PATH'].replace("\\", "/"))

image_metadata_dict = {}
for folder in base_path.iterdir():
    if folder.is_dir():
        image_metadata_dict.update(create_image_metadata_dict(folder))

# %%
image_metadata_dict
# Out:
# {'2012-08-25 13.03.40.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2012-08-25 13.03.40.jpg',
#   'filename': '2012-08-25 13.03.40.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2012, 8, 25, 13, 3, 40)},
#  '2012-08-25 13.03.47.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2012-08-25 13.03.47.jpg',
#   'filename': '2012-08-25 13.03.47.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2012, 8, 25, 13, 3, 47)},
#  '2012-08-25 13.04.30.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2012-08-25 13.04.30.jpg',
#   'filename': '2012-08-25 13.04.30.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2012, 8, 25, 13, 4, 30)},
#  '2012-08-25 13.04.32.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2012-08-25 13.04.32.jpg',
#   'filename': '2012-08-25 13.04.32.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2012, 8, 25, 13, 4, 32)},
#  '2012-08-25 13.07.39.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2012-08-25 13.07.39.jpg',
#   'filename': '2012-08-25 13.07.39.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2012, 8, 25, 13, 7, 39)},
#  '2012-08-25 13.39.21.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2012-08-25 13.39.21.jpg',
#   'filename': '2012-08-25 13.39.21.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2012, 8, 25, 13, 39, 21)},
#  '2012-08-25 13.45.21.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2012-08-25 13.45.21.jpg',
#   'filename': '2012-08-25 13.45.21.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2012, 8, 25, 13, 45, 21)},
#  '2012-08-25 13.45.28.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2012-08-25 13.45.28.jpg',
#   'filename': '2012-08-25 13.45.28.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2012, 8, 25, 13, 45, 28)},
#  '2012-08-25 14.35.37.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2012-08-25 14.35.37.jpg',
#   'filename': '2012-08-25 14.35.37.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2012, 8, 25, 14, 35, 37)},
#  '2012-08-25 14.35.40.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2012-08-25 14.35.40.jpg',
#   'filename': '2012-08-25 14.35.40.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2012, 8, 25, 14, 35, 40)},
#  '2012-08-25 14.35.42.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2012-08-25 14.35.42.jpg',
#   'filename': '2012-08-25 14.35.42.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2012, 8, 25, 14, 35, 42)},
#  '2012-08-25 15.05.29.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2012-08-25 15.05.29.jpg',
#   'filename': '2012-08-25 15.05.29.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2012, 8, 25, 15, 5, 29)},
#  '2012-08-25 15.05.30.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2012-08-25 15.05.30.jpg',
#   'filename': '2012-08-25 15.05.30.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2012, 8, 25, 15, 5, 30)},
#  '2012-08-25 15.05.33.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2012-08-25 15.05.33.jpg',
#   'filename': '2012-08-25 15.05.33.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2012, 8, 25, 15, 5, 33)},
#  '2012-08-25 15.05.41.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2012-08-25 15.05.41.jpg',
#   'filename': '2012-08-25 15.05.41.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2012, 8, 25, 15, 5,
jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2013-10-18 11.33.44.jpg',
#   'filename': '2013-10-18 11.33.44.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2013, 10, 18, 11, 33, 44)},
#  '2013-10-18 11.33.45.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2013-10-18 11.33.45.jpg',
#   'filename': '2013-10-18 11.33.45.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2013, 10, 18, 11, 33, 45)},
#  '2013-10-18 12.06.35.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2013-10-18 12.06.35.jpg',
#   'filename': '2013-10-18 12.06.35.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2013, 10, 18, 12, 6, 35)},
#  '2013-10-18 12.06.37.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2013-10-18 12.06.37.jpg',
#   'filename': '2013-10-18 12.06.37.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2013, 10, 18, 12, 6, 37)},
#  '2013-10-18 12.06.48.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2013-10-18 12.06.48.jpg',
#   'filename': '2013-10-18 12.06.48.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2013, 10, 18, 12, 6, 48)},
#  '2013-10-18 12.06.57.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2013-10-18 12.06.57.jpg',
#   'filename': '2013-10-18 12.06.57.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2013, 10, 18, 12, 6, 57)},
#  '2013-10-18 12.07.22.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2013-10-18 12.07.22.jpg',
#   'filename': '2013-10-18 12.07.22.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2013, 10, 18, 12, 7, 22)},
#  '2013-10-18 12.07.24.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2013-10-18 12.07.24.jpg',
#   'filename': '2013-10-18 12.07.24.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2013, 10, 18, 12, 7, 24)},
#  '2013-10-18 12.07.25.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2013-10-18 12.07.25.jpg',
#   'filename': '2013-10-18 12.07.25.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2013, 10, 18, 12, 7, 25)},
#  '2013-10-19 13.17.16.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2013-10-19 13.17.16.jpg',
#   'filename': '2013-10-19 13.17.16.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2013, 10, 19, 13, 17, 16)},
#  '2013-10-19 13.17.23.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2013-10-19 13.17.23.jpg',
#   'filename': '2013-10-19 13.17.23.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2013, 10, 19, 13, 17, 23)},
#  '2013-10-19 13.51.02.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2013-10-19 13.51.02.jpg',
#   'filename': '2013-10-19 13.51.02.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2013, 10, 19, 13, 51, 2)},
#  '2013-10-19 13.51.03.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2013-10-19 13.51.03.jpg',
#   'filename': '2013-10-19 13.51.03.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2013, 10, 19, 13, 51, 3)},
#  '2013-10-19 15.17.51.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2013-10-19 15.17.51.jpg',
#   'filename': '2013-10-19 15.17.51.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2013, 10, 19, 15, 17, 51)},
#  '2013-10-19 15.17.52.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2013-10-19 15.17.52.jpg',
#   'filename': '2013-10-19 15.17.52.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2013, 10, 19, 15, 17, 52)},
#  '2013-10-19 23.15.12.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2013-10-19 23.15.12.jpg',
#   'filename': '2013-10-19 23.15.12.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2013, 10, 19, 23, 15, 12)},
#  '2013-10-25 03.30.36.mp4': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2013-10-25 03.30.36.mp4',
#   'filename': '2013-10-25 03.30.36.mp4',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.mp4',
#   'timestamp': datetime.datetime(2013, 10, 25, 3, 30, 36)},
#  '2013-10-25 20.58.48.mp4': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2013-10-25 20.58.48.mp4',
#   'filename': '2013-10-25 20.58.48.mp4',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.mp4',
#   'timestamp': datetime.datetime(2013, 10, 25, 20, 58, 48)},
#  '2013-11-30 00.27.51.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2013-11-30 00.27.51.jpg',
#   'filename': '2013-11-30 00.27.51.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2013, 11, 30, 0, 27, 51)},
#  '2013-11-30 01.44.01.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2013-11-30 01.44.01.jpg',
#   'filename': '2013-11-30 01.44.01.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2013, 11, 30, 1, 44, 1)},
#  '2013-12-14 00.50.54.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2013-12-14 00.50.54.jpg',
#   'filename': '2013-12-14 00.50.54.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2013, 12, 14, 0, 50, 54)},
#  '2013-12-14 00.51.07.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2013-12-14 00.51.07.jpg',
#   'filename': '2013-12-14 00.51.07.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2013, 12, 14, 0, 51, 7)},
#  '2013-12-21 16.04.00.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2013-12-21 16.04.00.jpg',
#   'filename': '2013-12-21 16.04.00.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2013, 12, 21, 16, 4)},
#  '2013-12-21 16.44.02.mp4': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2013-12-21 16.44.02.mp4',
#   'filename': '2013-12-21 16.44.02.mp4',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.mp4',
#   'timestamp': datetime.datetime(2013, 12, 21, 16, 44, 2)},
#  '2013-12-27 21.43.58.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2013-12-27 21.43.58.jpg',
#   'filename': '2013-12-27 21.43.58.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2013, 12, 27, 21, 43, 58)},
#  '2013-12-27 21.44.11.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2013-12-27 21.44.11.jpg',
#   'filename': '2013-12-27 21.44.11.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2013, 12, 27, 21, 44, 11)},
#  '2013-12-28 23.45.35.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)/2013-12-28 23.45.35.jpg',
#   'filename': '2013-12-28 23.45.35.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/201312/Cargas de cámara (3)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2013, 12, 28, 23, 45, 35)},
#  '2014-01-01 12.22.37.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2014/Cargas de cámara (2)/2014-01-01 12.22.37.jpg',
#   'filename': '2014-01-01 12.22.37.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2014/Cargas de cámara (2)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2014, 1, 1, 12, 22, 37)},
#  '2014-01-01 12.22.43.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2014/Cargas de cámara (2)/2014-01-01 12.22.43.jpg',
#   'filename': '2014-01-01 12.22.43.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2014/Cargas de cámara (2)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2014, 1, 1, 12, 22, 43)},
#  '2014-01-01 12.22.48.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2014/Cargas de cámara (2)/2014-01-01 12.22.48.jpg',
#   'filename': '2014-01-01 12.22.48.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2014/Cargas de cámara (2)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2014, 1, 1, 12, 22, 48)},
#  '2014-01-01 13.22.20.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2014/Cargas de cámara (2)/2014-01-01 13.22.20.jpg',
#   'filename': '2014-01-01 13.22.20.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2014/Cargas de cámara (2)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2014, 1, 1, 13, 22, 20)},
#  '2014-01-03 18.16.24.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2014/Cargas de cámara (2)/2014-01-03 18.16.24.jpg',
#   'filename': '2014-01-03 18.16.24.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2014/Cargas de cámara (2)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2014, 1, 3, 18, 16, 24)},
#  '2014-01-08 21.57.59.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2014/Cargas de cámara (2)/2014-01-08 21.57.59.jpg',
#   'filename': '2014-01-08 21.57.59.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2014/Cargas de cámara (2)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2014, 1, 8, 21, 57, 59)},
#  '2014-01-08 21.58.13.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2014/Cargas de cámara (2)/2014-01-08 21.58.13.jpg',
#   'filename': '2014-01-08 21.58.13.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2014/Cargas de cámara (2)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2014, 1, 8, 21, 58, 13)},
#  '2014-01-11 20.16.14.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2014/Cargas de cámara (2)/2014-01-11 20.16.14.jpg',
#   'filename': '2014-01-11 20.16.14.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2014/Cargas de cámara (2)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2014, 1, 11, 20, 16, 14)},
#  '2014-01-12 20.29.52-1.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2014/Cargas de cámara (2)/2014-01-12 20.29.52-1.jpg',
#   'filename': '2014-01-12 20.29.52-1.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2014/Cargas de cámara (2)',
#   'file_suffix': '.jpg',
#   'timestamp': None},
#  '2014-01-12 20.29.52-2.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2014/Cargas de cámara (2)/2014-01-12 20.29.52-2.jpg',
#   'filename': '2014-01-12 20.29.52-2.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2014/Cargas de cámara (2)',
#   'file_suffix': '.jpg',
#   'timestamp': None},
#  '2014-01-12 20.29.53.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2014/Cargas de cámara (2)/2014-01-12 20.29.53.jpg',
#   'filename': '2014-01-12 20.29.53.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2014/Cargas de cámara (2)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2014, 1, 12, 20, 29, 53)},
#  '2014-01-12 20.38.22.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2014/Cargas de cámara (2)/2014-01-12 20.38.22.jpg',
#   'filename': '2014-01-12 20.38.22.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2014/Cargas de cámara (2)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2014, 1, 12, 20, 38, 22)},
#  '2014-01-12 20.38.48.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2014/Cargas de cámara (2)/2014-01-12 20.38.48.jpg',
#   'filename': '2014-01-12 20.38.48.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2014/Cargas de cámara (2)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2014, 1, 12, 20, 38, 48)},
#  '2014-01-12 20.38.50.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2014/Cargas de cámara (2)/2014-01-12 20.38.50.jpg',
#   'filename': '2014-01-12 20.38.50.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2014/Cargas de cámara (2)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2014, 1, 12, 20, 38, 50)},
#  '2014-01-12 20.38.51.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2014/Cargas de cámara (2)/2014-01-12 20.38.51.jpg',
#   'filename': '2014-01-12 20.38.51.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2014/Cargas de cámara (2)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2014, 1, 12, 20, 38, 51)},
#  '2014-01-12 20.38.53.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2014/Cargas de cámara (2)/2014-01-12 20.38.53.jpg',
#   'filename': '2014-01-12 20.38.53.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2014/Cargas de cámara (2)',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2014, 1, 12, 20, 38, 53)},
#  '2014-01-12 20.38.54.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2014/Cargas de cámara (2)/2014-01-12 20.38.54.jpg',
# ...
#   'filename': '2016-01-21 18.47.52.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2016/Cargas de cámara',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2016, 1, 21, 18, 47, 52)},
#  '2016-01-21 18.47.59.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2016/Cargas de cámara/2016-01-21 18.47.59.jpg',
#   'filename': '2016-01-21 18.47.59.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2016/Cargas de cámara',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2016, 1, 21, 18, 47, 59)},
#  '2016-01-21 19.37.11.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2016/Cargas de cámara/2016-01-21 19.37.11.jpg',
#   'filename': '2016-01-21 19.37.11.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2016/Cargas de cámara',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2016, 1, 21, 19, 37, 11)},
#  '2016-01-22 17.50.35.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2016/Cargas de cámara/2016-01-22 17.50.35.jpg',
#   'filename': '2016-01-22 17.50.35.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2016/Cargas de cámara',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2016, 1, 22, 17, 50, 35)},
#  '2016-01-22 21.56.16.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2016/Cargas de cámara/2016-01-22 21.56.16.jpg',
#   'filename': '2016-01-22 21.56.16.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2016/Cargas de cámara',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2016, 1, 22, 21, 56, 16)},
#  '2016-01-23 19.52.30.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2016/Cargas de cámara/2016-01-23 19.52.30.jpg',
#   'filename': '2016-01-23 19.52.30.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2016/Cargas de cámara',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2016, 1, 23, 19, 52, 30)},
#  '2016-01-25 14.14.49.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2016/Cargas de cámara/2016-01-25 14.14.49.jpg',
#   'filename': '2016-01-25 14.14.49.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2016/Cargas de cámara',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2016, 1, 25, 14, 14, 49)},
#  '2016-01-26 15.48.52.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2016/Cargas de cámara/2016-01-26 15.48.52.jpg',
#   'filename': '2016-01-26 15.48.52.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2016/Cargas de cámara',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2016, 1, 26, 15, 48, 52)},
#  '2016-01-26 15.48.58.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2016/Cargas de cámara/2016-01-26 15.48.58.jpg',
#   'filename': '2016-01-26 15.48.58.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2016/Cargas de cámara',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2016, 1, 26, 15, 48, 58)},
#  '2016-01-27 10.34.17.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2016/Cargas de cámara/2016-01-27 10.34.17.jpg',
#   'filename': '2016-01-27 10.34.17.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2016/Cargas de cámara',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2016, 1, 27, 10, 34, 17)},
#  '2016-01-27 10.34.23.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2016/Cargas de cámara/2016-01-27 10.34.23.jpg',
#   'filename': '2016-01-27 10.34.23.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2016/Cargas de cámara',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2016, 1, 27, 10, 34, 23)},
#  '2016-01-27 10.34.27.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2016/Cargas de cámara/2016-01-27 10.34.27.jpg',
#   'filename': '2016-01-27 10.34.27.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2016/Cargas de cámara',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2016, 1, 27, 10, 34, 27)},
#  '2016-01-27 17.59.30.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2016/Cargas de cámara/2016-01-27 17.59.30.jpg',
#   'filename': '2016-01-27 17.59.30.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2016/Cargas de cámara',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2016, 1, 27, 17, 59, 30)},
#  '2016-01-27 17.59.34.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2016/Cargas de cámara/2016-01-27 17.59.34.jpg',
#   'filename': '2016-01-27 17.59.34.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2016/Cargas de cámara',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2016, 1, 27, 17, 59, 34)},
#  '2016-01-28 15.56.50.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2016/Cargas de cámara/2016-01-28 15.56.50.jpg',
#   'filename': '2016-01-28 15.56.50.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2016/Cargas de cámara',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2016, 1, 28, 15, 56, 50)},
#  '2016-01-28 15.56.56.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2016/Cargas de cámara/2016-01-28 15.56.56.jpg',
#   'filename': '2016-01-28 15.56.56.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2016/Cargas de cámara',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2016, 1, 28, 15, 56, 56)},
#  '2016-01-28 15.57.12.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2016/Cargas de cámara/2016-01-28 15.57.12.jpg',
#   'filename': '2016-01-28 15.57.12.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2016/Cargas de cámara',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2016, 1, 28, 15, 57, 12)},
#  '2016-01-30 03.09.59.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2016/Cargas de cámara/2016-01-30 03.09.59.jpg',
#   'filename': '2016-01-30 03.09.59.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2016/Cargas de cámara',
#   'file_suffix': '.jpg',
#   'timestamp': datetime.datetime(2016, 1, 30, 3, 9, 59)},
#  'BAYC3828.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads/BAYC3828.jpg',
#   'filename': 'BAYC3828.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads',
#   'file_suffix': '.jpg',
#   'timestamp': None},
#  'DNAA9129.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads/DNAA9129.jpg',
#   'filename': 'DNAA9129.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads',
#   'file_suffix': '.jpg',
#   'timestamp': None},
#  'EONA2997.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads/EONA2997.jpg',
#   'filename': 'EONA2997.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads',
#   'file_suffix': '.jpg',
#   'timestamp': None},
#  'IMG-20160405-WA0003.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads/IMG-20160405-WA0003.jpg',
#   'filename': 'IMG-20160405-WA0003.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads',
#   'file_suffix': '.jpg',
#   'timestamp': None},
#  'IMG-20160405-WA0004.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads/IMG-20160405-WA0004.jpg',
#   'filename': 'IMG-20160405-WA0004.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads',
#   'file_suffix': '.jpg',
#   'timestamp': None},
#  'IMG-20160405-WA0005.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads/IMG-20160405-WA0005.jpg',
#   'filename': 'IMG-20160405-WA0005.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads',
#   'file_suffix': '.jpg',
#   'timestamp': None},
#  'IMG-20160405-WA0006.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads/IMG-20160405-WA0006.jpg',
#   'filename': 'IMG-20160405-WA0006.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads',
#   'file_suffix': '.jpg',
#   'timestamp': None},
#  'IMG-20160405-WA0007.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads/IMG-20160405-WA0007.jpg',
#   'filename': 'IMG-20160405-WA0007.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads',
#   'file_suffix': '.jpg',
#   'timestamp': None},
#  'IMG-20160405-WA0020.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads/IMG-20160405-WA0020.jpg',
#   'filename': 'IMG-20160405-WA0020.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads',
#   'file_suffix': '.jpg',
#   'timestamp': None},
#  'IMG-20160408-WA0072.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads/IMG-20160408-WA0072.jpg',
#   'filename': 'IMG-20160408-WA0072.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads',
#   'file_suffix': '.jpg',
#   'timestamp': None},
#  'IMG-20160408-WA0073.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads/IMG-20160408-WA0073.jpg',
#   'filename': 'IMG-20160408-WA0073.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads',
#   'file_suffix': '.jpg',
#   'timestamp': None},
#  'IMG_2318.JPG': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads/IMG_2318.JPG',
#   'filename': 'IMG_2318.JPG',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads',
#   'file_suffix': '.JPG',
#   'timestamp': None},
#  'IMG_2562.JPG': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads/IMG_2562.JPG',
#   'filename': 'IMG_2562.JPG',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads',
#   'file_suffix': '.JPG',
#   'timestamp': None},
#  'IMG_2578.JPG': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads/IMG_2578.JPG',
#   'filename': 'IMG_2578.JPG',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads',
#   'file_suffix': '.JPG',
#   'timestamp': None},
#  'IMG_2581.JPG': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads/IMG_2581.JPG',
#   'filename': 'IMG_2581.JPG',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads',
#   'file_suffix': '.JPG',
#   'timestamp': None},
#  'IMG_2581.MOV': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads/IMG_2581.MOV',
#   'filename': 'IMG_2581.MOV',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads',
#   'file_suffix': '.MOV',
#   'timestamp': None},
#  'IMG_2595.JPG': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads/IMG_2595.JPG',
#   'filename': 'IMG_2595.JPG',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads',
#   'file_suffix': '.JPG',
#   'timestamp': None},
#  'IMG_2596.JPG': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads/IMG_2596.JPG',
#   'filename': 'IMG_2596.JPG',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads',
#   'file_suffix': '.JPG',
#   'timestamp': None},
#  'IMG_2771.MOV': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads/IMG_2771.MOV',
#   'filename': 'IMG_2771.MOV',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads',
#   'file_suffix': '.MOV',
#   'timestamp': None},
#  'IMG_2946.JPG': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads/IMG_2946.JPG',
#   'filename': 'IMG_2946.JPG',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads',
#   'file_suffix': '.JPG',
#   'timestamp': None},
#  'IMG_3299.JPG': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads/IMG_3299.JPG',
#   'filename': 'IMG_3299.JPG',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads',
#   'file_suffix': '.JPG',
#   'timestamp': None},
#  'IMG_4337.JPG': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads/IMG_4337.JPG',
#   'filename': 'IMG_4337.JPG',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads',
#   'file_suffix': '.JPG',
#   'timestamp': None},
#  'IMG_5306.JPG': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads/IMG_5306.JPG',
#   'filename': 'IMG_5306.JPG',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads',
#   'file_suffix': '.JPG',
#   'timestamp': None},
#  'IMG_5310.JPG': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads/IMG_5310.JPG',
#   'filename': 'IMG_5310.JPG',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads',
#   'file_suffix': '.JPG',
#   'timestamp': None},
#  'IMG_5314.JPG': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads/IMG_5314.JPG',
#   'filename': 'IMG_5314.JPG',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads',
#   'file_suffix': '.JPG',
#   'timestamp': None},
#  'IMG_5315.JPG': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads/IMG_5315.JPG',
#   'filename': 'IMG_5315.JPG',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads',
#   'file_suffix': '.JPG',
#   'timestamp': None},
#  'IMG_5316.JPG': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads/IMG_5316.JPG',
#   'filename': 'IMG_5316.JPG',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads',
#   'file_suffix': '.JPG',
#   'timestamp': None},
#  'IMG_5317.JPG': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads/IMG_5317.JPG',
#   'filename': 'IMG_5317.JPG',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads',
#   'file_suffix': '.JPG',
#   'timestamp': None},
#  'IMG_5318.mp4': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads/IMG_5318.mp4',
#   'filename': 'IMG_5318.mp4',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads',
#   'file_suffix': '.mp4',
#   'timestamp': None},
#  'IMG_5382.JPG': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads/IMG_5382.JPG',
#   'filename': 'IMG_5382.JPG',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads',
#   'file_suffix': '.JPG',
#   'timestamp': None},
#  'IMG_5481.JPG': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads/IMG_5481.JPG',
#   'filename': 'IMG_5481.JPG',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads',
#   'file_suffix': '.JPG',
#   'timestamp': None},
#  'IMG_5482.JPG': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads/IMG_5482.JPG',
#   'filename': 'IMG_5482.JPG',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads',
#   'file_suffix': '.JPG',
#   'timestamp': None},
#  'IMG_6504.MOV': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads/IMG_6504.MOV',
#   'filename': 'IMG_6504.MOV',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads',
#   'file_suffix': '.MOV',
#   'timestamp': None},
#  'MZXA7565.jpg': {'img_url': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads/MZXA7565.jpg',
#   'filename': 'MZXA7565.jpg',
#   'folderpath': 'C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/Downloads',
#   'file_suffix': '.jpg',
#   'timestamp': None}}

# %%
from PIL import Image

def convert_png_to_jpg(img_name):
    im = Image.open(image_metadata_dict[img_name].get('img_url'))
    rgb_im = im.convert('RGB')
    rgb_im.save(image_metadata_dict[img_name].get('img_url').replace('.png', '.jpg'))
    image_metadata_dict[img_name]['img_url'] = image_metadata_dict[img_name].get('img_url').replace('.png', '.jpg')
    image_metadata_dict[img_name]['file_suffix'] = '.jpg'
    image_metadata_dict[img_name]['filename'] = image_metadata_dict[img_name].get('filename').replace('.png', '.jpg')

# %%
import piexif

def set_exif_timestamp(img_name):
    timestamp = image_metadata_dict[img_name].get('timestamp')
    
    if not timestamp:
        print(f"[WARNING] No timestamp found for {img_name}. Skipping EXIF writing.")
        return

    img_url = image_metadata_dict[img_name]['img_url']
    formatted_time = timestamp.strftime("%Y:%m:%d %H:%M:%S")
    try:
        exif_dict = piexif.load(image_metadata_dict[img_name].get('img_url'))

        exif_dict['Exif'][piexif.ExifIFD.DateTimeOriginal] = formatted_time.encode()
        exif_dict['0th'][piexif.ImageIFD.DateTime] = formatted_time.encode()

        exif_bytes = piexif.dump(exif_dict)
        piexif.insert(exif_bytes, image_metadata_dict[img_name].get('img_url'))
    
    except Exception as e:
          print(f"[ERROR] Failed to set EXIF timestamp for {img_url}: {e}")

# %%
def prepare_image_for_upload(img_name):
    image_path = Path(image_metadata_dict[img_name].get('img_url'))
    timestamp = image_metadata_dict[img_name].get('timestamp', None)
    
    if image_path.suffix.lower() == '.png':
        convert_png_to_jpg(img_name)

    if timestamp:
        set_exif_timestamp(img_name)
    else:
        print(f"No valid timestamp for {image_path}")

# %%
from google_auth_oauthlib.flow import InstalledAppFlow
from google.oauth2.credentials import Credentials
from googleapiclient.discovery import build
import os

class GooglePhotosClient:
    def __init__(self, credentials_json_path, token_json_path, scopes):
        self.credentials_json_path = credentials_json_path
        self.token_json_path = token_json_path
        self.scopes = scopes
        self.creds = None
        self.service = None
        self.authenticate()

    def authenticate(self):
        if os.path.exists(self.token_json_path):
            self.creds = Credentials.from_authorized_user_file(self.token_json_path, self.scopes)
            print("Loaded credentials from token file.")
        else:
            flow = InstalledAppFlow.from_client_secrets_file(self.credentials_json_path, self.scopes)
            self.creds = flow.run_local_server() # if it's a pyfile flow.run_console()
            with open(self.token_json_path, 'w') as token_file:
                token_file.write(self.creds.to_json())
            print("Authentication complete. Token saved.")

        self.service = build('photoslibrary', 'v1', credentials=self.creds)

    def get_service(self):
        return self.service

# %%
import requests
from google.auth.transport.requests import Request

def upload_image(image_path, creds):
    if creds.expired and creds.refresh_token:
        creds.refresh(Request())
        print(f"[INFO] Refreshed access token.")
    headers = {
        'Authorization': f'Bearer {creds.token}',
        'Content-type': 'application/octet-stream',
        'X-Goog-Upload-File-Name': os.path.basename(image_path),
        'X-Goog-Upload-Protocol': 'raw',
    }

    with open(image_path, 'rb') as f:
        response = requests.post(
            url='https://photoslibrary.googleapis.com/v1/uploads',
            data=f,
            headers=headers
        )

    if response.status_code == 200:
        upload_token = response.text
        print(f"[INFO] Uploaded {image_path} - got uploadToken.")
        return upload_token
    else:
        print(f"[ERROR] Failed to upload {image_path}: {response.text}")
        return None

# %%
def create_media_item(upload_token, description, creds):
    service = build('photoslibrary', 'v1', credentials=creds)
    body = {
        "newMediaItems": [
            {
                "description": description,
                "simpleMediaItem": {
                    "uploadToken": upload_token
                }
            }
        ]
    }

    response = service.mediaItems().batchCreate(body=body).execute()
    return response

# %%
def upload_image_with_metadata(client, img_name):
    img_url = image_metadata_dict[img_name]['img_url']
    folderpath = image_metadata_dict[img_name]['folderpath']

    print(f"[INFO] Uploading image: {img_url}")

    upload_token = upload_image(img_url, client.creds)
    if not upload_token:
        print(f"[ERROR] Skipping {img_url} due to failed upload.")
        return

    description = f"File date:{image_metadata_dict[img_name].get('timestamp')}"
    result = create_media_item(upload_token, description, client.creds)

# %%
# Initialize your client
client = GooglePhotosClient(
    credentials_json_path=os.environ['GOOGLE_CLIENT_SECRET_JSON'],
    token_json_path='../credentials/token.json',
    scopes=['https://www.googleapis.com/auth/photoslibrary.appendonly']
)
# Out:
# Loaded credentials from token file.

# %%
# Run the full process
for img_name in ['2016-01-07 16.05.27.jpg']:
    prepare_image_for_upload(img_name)
    upload_image_with_metadata(client, img_name)
# Out:
# [ERROR] Failed to set EXIF timestamp for C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2016/Cargas de cámara/2016-01-07 16.05.27.jpg: [Errno 2] No such file or directory: '2016-01-07 16.05.27.jpg'
# [INFO] Uploading image: C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2016/Cargas de cámara/2016-01-07 16.05.27.jpg
# [INFO] Refreshed access token.
# [INFO] Uploaded C:/Users/Facundo Toneguzzo/OneDrive/Escritorio/Dropbox/2016/Cargas de cámara/2016-01-07 16.05.27.jpg - got uploadToken.
